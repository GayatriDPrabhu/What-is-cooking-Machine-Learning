# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('5-nn1.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('5-NNClassifier1', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('5-nn2.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('5-NNClassifier2', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('5-nn3.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('5-NNClassifier3', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('5-nn4.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('5-NNClassifier4', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('7-nn1.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('7-NNClassifier1', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('7-nn2.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('7-NNClassifier2', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('7-nn3.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('7-NNClassifier3', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('7-nn4.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('7-NNClassifier4', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()
