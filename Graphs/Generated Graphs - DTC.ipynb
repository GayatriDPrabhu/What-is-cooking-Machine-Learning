# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('dtc1.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('decisionTreeClassifier1', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('dtc2.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('decisionTreeClassifier2', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('dtc3.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('decisionTreeClassifier3', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()

# %%
# %config IPCompleter.greedy=True

import pandas
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pandas.read_csv('dtc4.csv')

cuisine_count  = train_df['cuisine'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(cuisine_count.values, cuisine_count.index, alpha=1.0)
plt.title('decisionTreeClassifier4', fontsize=18)
plt.ylabel('Name of cuisine', fontsize=14)
plt.xlabel('# of recipes', fontsize=14)
plt.show()
